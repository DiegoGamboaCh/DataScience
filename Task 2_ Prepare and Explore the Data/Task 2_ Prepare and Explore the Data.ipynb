# %% [markdown]
# # Reading Data & Configuration

# %%
import pandas as pd
import numpy as np

# %%
credit = pd.read_csv('C:\\Util\\Cenfotec\\Module5_Task2\\default of credit card clients.csv', header =1)

# %%
#simply view a quick sample the dataframe by calling the name in a cell
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0                           1
# 1      1000         0      2000                           1
# 2      1000      1000      5000                           0
# 3      1100      1069      1000                           0
# 4      9000       689       679                           0
#
# [5 rows x 25 columns]

# %%
#What type credit
type(credit)
# Out:
# pandas.core.frame.DataFrame

# %%
#understand the makeup of the data (like funsction summary() in R)
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# std        9.217904      1.123802      1.197186      1.196868      1.169139
# min       21.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       28.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%       34.000000      0.000000      0.000000      0.000000      0.000000
# 75%       41.000000      0.000000      0.000000      0.000000      0.000000
# max       79.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count  ...   30000.000000   30000.000000   30000.000000   30000.000000
# mean   ...   43262.948967   40311.400967   38871.760400    5663.580500
# std    ...   64332.856134   60797.155770   59554.107537   16563.280354
# min    ... -170000.000000  -81334.000000 -339603.000000       0.000000
# 25%    ...    2326.750000    1763.000000    1256.000000    1000.000000
# 50%    ...   19052.000000   18104.500000   17071.000000    2100.000000
# 75%    ...   54506.000000   50190.500000   49198.250000    5006.000000
# max    ...  891586.000000  927171.000000  961664.000000  873552.000000
#
#            PAY_AMT2      PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  3.000000e+04   30000.00000   30000.000000   30000.000000
# mean   5.921163e+03    5225.68150    4826.076867    4799.387633
# std    2.304087e+04   17606.96147   15666.159744   15278.305679
# min    0.000000e+00       0.00000       0.000000       0.000000
# 25%    8.330000e+02     390.00000     296.000000     252.500000
# 50%    2.009000e+03    1800.00000    1500.000000    1500.000000
# 75%    5.000000e+03    4505.00000    4013.250000    4031.500000
# max    1.684259e+06  896040.00000  621000.000000  426529.000000
#
#             PAY_AMT6  default payment next month
# count   30000.000000                30000.000000
# mean     5215.502567                    0.221200
# std     17777.465775                    0.415062
# min         0.000000                    0.000000
# 25%       117.750000                    0.000000
# 50%      1500.000000                    0.000000
# 75%      4000.000000                    0.000000
# max    528666.000000                    1.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# # Cleaning

# %%
#check the data types of each variable
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# BILL_AMT5                     30000 non-null int64
# BILL_AMT6                     30000 non-null int64
# PAY_AMT1                      30000 non-null int64
# PAY_AMT2                      30000 non-null int64
# PAY_AMT3                      30000 non-null int64
# PAY_AMT4                      30000 non-null int64
# PAY_AMT5                      30000 non-null int64
# PAY_AMT6                      30000 non-null int64
# default payment next month    30000 non-null int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %%
pd.isnull(credit['SEX'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29995    False
# 29996    False
# 29997    False
# 29998    False
# 29999    False
# Name: SEX, Length: 30000, dtype: bool

# %%
#Is NaN
credit.isnull()
# Out:
#           ID  LIMIT_BAL    SEX  EDUCATION  MARRIAGE    AGE  PAY_0  PAY_2  \
# 0      False      False  False      False     False  False  False  False
# 1      False      False  False      False     False  False  False  False
# 2      False      False  False      False     False  False  False  False
# 3      False      False  False      False     False  False  False  False
# 4      False      False  False      False     False  False  False  False
# ...      ...        ...    ...        ...       ...    ...    ...    ...
# 29995  False      False  False      False     False  False  False  False
# 29996  False      False  False      False     False  False  False  False
# 29997  False      False  False      False     False  False  False  False
# 29998  False      False  False      False     False  False  False  False
# 29999  False      False  False      False     False  False  False  False
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0      False  False  ...      False      False      False     False     False
# 1      False  False  ...      False      False      False     False     False
# 2      False  False  ...      False      False      False     False     False
# 3      False  False  ...      False      False      False     False     False
# 4      False  False  ...      False      False      False     False     False
# ...      ...    ...  ...        ...        ...        ...       ...       ...
# 29995  False  False  ...      False      False      False     False     False
# 29996  False  False  ...      False      False      False     False     False
# 29997  False  False  ...      False      False      False     False     False
# 29998  False  False  ...      False      False      False     False     False
# 29999  False  False  ...      False      False      False     False     False
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         False     False     False     False                       False
# 1         False     False     False     False                       False
# 2         False     False     False     False                       False
# 3         False     False     False     False                       False
# 4         False     False     False     False                       False
# ...         ...       ...       ...       ...                         ...
# 29995     False     False     False     False                       False
# 29996     False     False     False     False                       False
# 29997     False     False     False     False                       False
# 29998     False     False     False     False                       False
# 29999     False     False     False     False                       False
#
# [30000 rows x 25 columns]

# %%
#Is not NaN
credit.notnull()
# Out:
#          ID  LIMIT_BAL   SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  \
# 0      True       True  True       True      True  True   True   True   True
# 1      True       True  True       True      True  True   True   True   True
# 2      True       True  True       True      True  True   True   True   True
# 3      True       True  True       True      True  True   True   True   True
# 4      True       True  True       True      True  True   True   True   True
# ...     ...        ...   ...        ...       ...   ...    ...    ...    ...
# 29995  True       True  True       True      True  True   True   True   True
# 29996  True       True  True       True      True  True   True   True   True
# 29997  True       True  True       True      True  True   True   True   True
# 29998  True       True  True       True      True  True   True   True   True
# 29999  True       True  True       True      True  True   True   True   True
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0       True  ...       True       True       True      True      True
# 1       True  ...       True       True       True      True      True
# 2       True  ...       True       True       True      True      True
# 3       True  ...       True       True       True      True      True
# 4       True  ...       True       True       True      True      True
# ...      ...  ...        ...        ...        ...       ...       ...
# 29995   True  ...       True       True       True      True      True
# 29996   True  ...       True       True       True      True      True
# 29997   True  ...       True       True       True      True      True
# 29998   True  ...       True       True       True      True      True
# 29999   True  ...       True       True       True      True      True
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0          True      True      True      True                        True
# 1          True      True      True      True                        True
# 2          True      True      True      True                        True
# 3          True      True      True      True                        True
# 4          True      True      True      True                        True
# ...         ...       ...       ...       ...                         ...
# 29995      True      True      True      True                        True
# 29996      True      True      True      True                        True
# 29997      True      True      True      True                        True
# 29998      True      True      True      True                        True
# 29999      True      True      True      True                        True
#
# [30000 rows x 25 columns]

# %%
# ask for total missing values by column
credit.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
#	Drop	rows	with	any	column	having	NA/null	data.	
drop_credit = credit.dropna()

# %%
drop_credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# std        9.217904      1.123802      1.197186      1.196868      1.169139
# min       21.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       28.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%       34.000000      0.000000      0.000000      0.000000      0.000000
# 75%       41.000000      0.000000      0.000000      0.000000      0.000000
# max       79.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count  ...   30000.000000   30000.000000   30000.000000   30000.000000
# mean   ...   43262.948967   40311.400967   38871.760400    5663.580500
# std    ...   64332.856134   60797.155770   59554.107537   16563.280354
# min    ... -170000.000000  -81334.000000 -339603.000000       0.000000
# 25%    ...    2326.750000    1763.000000    1256.000000    1000.000000
# 50%    ...   19052.000000   18104.500000   17071.000000    2100.000000
# 75%    ...   54506.000000   50190.500000   49198.250000    5006.000000
# max    ...  891586.000000  927171.000000  961664.000000  873552.000000
#
#            PAY_AMT2      PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  3.000000e+04   30000.00000   30000.000000   30000.000000
# mean   5.921163e+03    5225.68150    4826.076867    4799.387633
# std    2.304087e+04   17606.96147   15666.159744   15278.305679
# min    0.000000e+00       0.00000       0.000000       0.000000
# 25%    8.330000e+02     390.00000     296.000000     252.500000
# 50%    2.009000e+03    1800.00000    1500.000000    1500.000000
# 75%    5.000000e+03    4505.00000    4013.250000    4031.500000
# max    1.684259e+06  896040.00000  621000.000000  426529.000000
#
#             PAY_AMT6  default payment next month
# count   30000.000000                30000.000000
# mean     5215.502567                    0.221200
# std     17777.465775                    0.415062
# min         0.000000                    0.000000
# 25%       117.750000                    0.000000
# 50%      1500.000000                    0.000000
# 75%      4000.000000                    0.000000
# max    528666.000000                    1.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# # Reading Data & Configuration with Dora

# %%
#Dora is a Python library designed to automate the painful parts of exploratory data analysis.
#The library contains convenience functions for data cleaning, feature selection & extraction, visualization,
#partitioning data for model validation, and versioning transformations of data.

#The library uses and is intended to be a helpful addition to common Python data analysis tools such as pandas, 
#scikit-learn, and matplotlib.
#read data with missing and poorly scaled values

# pip install Dora
from Dora import Dora

# %%
# without initial config
dora = Dora()
dora.configure(output = 'A', data = 'C:\\Util\\Cenfotec\\Module5_Task2\\default of credit card clients.csv')

# %%
dora.data
# Out:
#       Unnamed: 0         X1   X2         X3        X4   X5     X6     X7  \
# 0             ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2
# 1              1      20000    2          2         1   24      2      2
# 2              2     120000    2          2         2   26     -1      2
# 3              3      90000    2          2         2   34      0      0
# 4              4      50000    2          2         1   37      0      0
# ...          ...        ...  ...        ...       ...  ...    ...    ...
# 29996      29996     220000    1          3         1   39      0      0
# 29997      29997     150000    1          3         2   43     -1     -1
# 29998      29998      30000    1          2         2   37      4      3
# 29999      29999      80000    1          3         1   41      1     -1
# 30000      30000      50000    1          2         1   46      0      0
#
#           X8     X9  ...        X15        X16        X17       X18       X19  \
# 0      PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2
# 1         -1     -1  ...          0          0          0         0       689
# 2          0      0  ...       3272       3455       3261         0      1000
# 3          0      0  ...      14331      14948      15549      1518      1500
# 4          0      0  ...      28314      28959      29547      2000      2019
# ...      ...    ...  ...        ...        ...        ...       ...       ...
# 29996      0      0  ...      88004      31237      15980      8500     20000
# 29997     -1     -1  ...       8979       5190          0      1837      3526
# 29998      2     -1  ...      20878      20582      19357         0         0
# 29999      0      0  ...      52774      11855      48944     85900      3409
# 30000      0      0  ...      36535      32428      15313      2078      1800
#
#             X20       X21       X22       X23                           Y
# 0      PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 1             0         0         0         0                           1
# 2          1000      1000         0      2000                           1
# 3          1000      1000      1000      5000                           0
# 4          1200      1100      1069      1000                           0
# ...         ...       ...       ...       ...                         ...
# 29996      5003      3047      5000      1000                           0
# 29997      8998       129         0         0                           0
# 29998     22000      4200      2000      3100                           1
# 29999      1178      1926     52964      1804                           1
# 30000      1430      1000      1000      1000                           1
#
# [30001 rows x 25 columns]

# %% [markdown]
# # Cleaning: Dropping Columns in a DataFrame

# %%
#Correlation Matrix
credit.corr()
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# BILL_AMT2                   0.017982   0.278314 -0.031183   0.018749
# BILL_AMT3                   0.024354   0.283236 -0.024563   0.013002
# BILL_AMT4                   0.040351   0.293988 -0.021880  -0.000451
# BILL_AMT5                   0.016705   0.295562 -0.017005  -0.007567
# BILL_AMT6                   0.016730   0.290389 -0.016733  -0.009099
# PAY_AMT1                    0.009742   0.195236 -0.000242  -0.037456
# PAY_AMT2                    0.008406   0.178408 -0.001391  -0.030038
# PAY_AMT3                    0.039151   0.210167 -0.008597  -0.039943
# PAY_AMT4                    0.007793   0.203242 -0.002229  -0.038218
# PAY_AMT5                    0.000652   0.217202 -0.001667  -0.040358
# PAY_AMT6                    0.003000   0.219595 -0.002766  -0.037200
# default payment next month -0.013952  -0.153520 -0.039961   0.028006
#
#                             MARRIAGE       AGE     PAY_0     PAY_2     PAY_3  \
# ID                         -0.029079  0.018678 -0.030575 -0.011215 -0.018494
# LIMIT_BAL                  -0.108139  0.144713 -0.271214 -0.296382 -0.286123
# SEX                        -0.031389 -0.090874 -0.057643 -0.070771 -0.066096
# EDUCATION                  -0.143464  0.175061  0.105364  0.121566  0.114025
# MARRIAGE                    1.000000 -0.414170  0.019917  0.024199  0.032688
# AGE                        -0.414170  1.000000 -0.039447 -0.050148 -0.053048
# PAY_0                       0.019917 -0.039447  1.000000  0.672164  0.574245
# PAY_2                       0.024199 -0.050148  0.672164  1.000000  0.766552
# PAY_3                       0.032688 -0.053048  0.574245  0.766552  1.000000
# PAY_4                       0.033122 -0.049722  0.538841  0.662067  0.777359
# PAY_5                       0.035629 -0.053826  0.509426  0.622780  0.686775
# PAY_6                       0.034345 -0.048773  0.474553  0.575501  0.632684
# BILL_AMT1                  -0.023472  0.056239  0.187068  0.234887  0.208473
# BILL_AMT2                  -0.021602  0.054283  0.189859  0.235257  0.237295
# BILL_AMT3                  -0.024909  0.053710  0.179785  0.224146  0.227494
# BILL_AMT4                  -0.023344  0.051353  0.179125  0.222237  0.227202
# BILL_AMT5                  -0.025393  0.049345  0.180635  0.221348  0.225145
# BILL_AMT6                  -0.021207  0.047613  0.176980  0.219403  0.222327
# PAY_AMT1                   -0.005979  0.026147 -0.079269 -0.080701  0.001295
# PAY_AMT2                   -0.008093  0.021785 -0.070101 -0.058990 -0.066793
# PAY_AMT3                   -0.003541  0.029247 -0.070561 -0.055901 -0.053311
# PAY_AMT4                   -0.012659  0.021379 -0.064005 -0.046858 -0.046067
# PAY_AMT5                   -0.001205  0.022850 -0.058190 -0.037093 -0.035863
# PAY_AMT6                   -0.006641  0.019478 -0.058673 -0.036500 -0.035861
# default payment next month -0.024339  0.013890  0.324794  0.263551  0.235253
#
#                                PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# ID                         -0.002735  ...   0.040351   0.016705   0.016730
# LIMIT_BAL                  -0.267460  ...   0.293988   0.295562   0.290389
# SEX                        -0.060173  ...  -0.021880  -0.017005  -0.016733
# EDUCATION                   0.108793  ...  -0.000451  -0.007567  -0.009099
# MARRIAGE                    0.033122  ...  -0.023344  -0.025393  -0.021207
# AGE                        -0.049722  ...   0.051353   0.049345   0.047613
# PAY_0                       0.538841  ...   0.179125   0.180635   0.176980
# PAY_2                       0.662067  ...   0.222237   0.221348   0.219403
# PAY_3                       0.777359  ...   0.227202   0.225145   0.222327
# PAY_4                       1.000000  ...   0.245917   0.242902   0.239154
# PAY_5                       0.819835  ...   0.271915   0.269783   0.262509
# PAY_6                       0.716449  ...   0.266356   0.290894   0.285091
# BILL_AMT1                   0.202812  ...   0.860272   0.829779   0.802650
# BILL_AMT2                   0.225816  ...   0.892482   0.859778   0.831594
# BILL_AMT3                   0.244983  ...   0.923969   0.883910   0.853320
# BILL_AMT4                   0.245917  ...   1.000000   0.940134   0.900941
# BILL_AMT5                   0.242902  ...   0.940134   1.000000   0.946197
# BILL_AMT6                   0.239154  ...   0.900941   0.946197   1.000000
# PAY_AMT1                   -0.009362  ...   0.233012   0.217031   0.199965
# PAY_AMT2                   -0.001944  ...   0.207564   0.181246   0.172663
# PAY_AMT3                   -0.069235  ...   0.300023   0.252305   0.233770
# PAY_AMT4                   -0.043461  ...   0.130191   0.293118   0.250237
# PAY_AMT5                   -0.033590  ...   0.160433   0.141574   0.307729
# PAY_AMT6                   -0.026565  ...   0.177637   0.164184   0.115494
# default payment next month  0.216614  ...  -0.010156  -0.006760  -0.005372
#
#                             PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# ID                          0.009742  0.008406  0.039151  0.007793  0.000652
# LIMIT_BAL                   0.195236  0.178408  0.210167  0.203242  0.217202
# SEX                        -0.000242 -0.001391 -0.008597 -0.002229 -0.001667
# EDUCATION                  -0.037456 -0.030038 -0.039943 -0.038218 -0.040358
# MARRIAGE                   -0.005979 -0.008093 -0.003541 -0.012659 -0.001205
# AGE                         0.026147  0.021785  0.029247  0.021379  0.022850
# PAY_0                      -0.079269 -0.070101 -0.070561 -0.064005 -0.058190
# PAY_2                      -0.080701 -0.058990 -0.055901 -0.046858 -0.037093
# PAY_3                       0.001295 -0.066793 -0.053311 -0.046067 -0.035863
# PAY_4                      -0.009362 -0.001944 -0.069235 -0.043461 -0.033590
# PAY_5                      -0.006089 -0.003191  0.009062 -0.058299 -0.033337
# PAY_6                      -0.001496 -0.005223  0.005834  0.019018 -0.046434
# BILL_AMT1                   0.140277  0.099355  0.156887  0.158303  0.167026
# BILL_AMT2                   0.280365  0.100851  0.150718  0.147398  0.157957
# BILL_AMT3                   0.244335  0.316936  0.130011  0.143405  0.179712
# BILL_AMT4                   0.233012  0.207564  0.300023  0.130191  0.160433
# BILL_AMT5                   0.217031  0.181246  0.252305  0.293118  0.141574
# BILL_AMT6                   0.199965  0.172663  0.233770  0.250237  0.307729
# PAY_AMT1                    1.000000  0.285576  0.252191  0.199558  0.148459
# PAY_AMT2                    0.285576  1.000000  0.244770  0.180107  0.180908
# PAY_AMT3                    0.252191  0.244770  1.000000  0.216325  0.159214
# PAY_AMT4                    0.199558  0.180107  0.216325  1.000000  0.151830
# PAY_AMT5                    0.148459  0.180908  0.159214  0.151830  1.000000
# PAY_AMT6                    0.185735  0.157634  0.162740  0.157834  0.154896
# default payment next month -0.072929 -0.058579 -0.056250 -0.056827 -0.055124
#
#                             PAY_AMT6  default payment next month
# ID                          0.003000                   -0.013952
# LIMIT_BAL                   0.219595                   -0.153520
# SEX                        -0.002766                   -0.039961
# EDUCATION                  -0.037200                    0.028006
# MARRIAGE                   -0.006641                   -0.024339
# AGE                         0.019478                    0.013890
# PAY_0                      -0.058673                    0.324794
# PAY_2                      -0.036500                    0.263551
# PAY_3                      -0.035861                    0.235253
# PAY_4                      -0.026565                    0.216614
# PAY_5                      -0.023027                    0.204149
# PAY_6                      -0.025299                    0.186866
# BILL_AMT1                   0.179341                   -0.019644
# BILL_AMT2                   0.174256                   -0.014193
# BILL_AMT3                   0.182326                   -0.014076
# BILL_AMT4                   0.177637                   -0.010156
# BILL_AMT5                   0.164184                   -0.006760
# BILL_AMT6                   0.115494                   -0.005372
# PAY_AMT1                    0.185735                   -0.072929
# PAY_AMT2                    0.157634                   -0.058579
# PAY_AMT3                    0.162740                   -0.056250
# PAY_AMT4                    0.157834                   -0.056827
# PAY_AMT5                    0.154896                   -0.055124
# PAY_AMT6                    1.000000                   -0.053183
# default payment next month -0.053183                    1.000000
#
# [25 rows x 25 columns]

# %%
corrMatrix = credit.corr()
corrMatrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col1 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col2 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col3 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col4 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col5 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col6 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col7 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col8 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col9 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col10 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col11 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col12 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col13 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col14 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col15 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col16 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col17 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col18 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col19 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col20 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col21 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col22 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col23 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow0_col24 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col0 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col2 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col4 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col5 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col12 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col13 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col14 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col15 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col16 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col17 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col18 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col19 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col20 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col21 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col22 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col23 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow1_col24 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow2_col0 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow2_col1 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow2_col3 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow2_col4 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow2_col5 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow2_col6 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow2_col7 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow2_col8 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_8c332ee6_5bed_11ea_a8b5_c8f75055777arow2_col9 {
#             background-color:  #6e90f2;

# %%
credit.corr().unstack().sort_values().drop_duplicates()
# Out:
# AGE        MARRIAGE    -0.414170
# LIMIT_BAL  PAY_2       -0.296382
#            PAY_3       -0.286123
#            PAY_0       -0.271214
#            PAY_4       -0.267460
#                           ...
# BILL_AMT2  BILL_AMT3    0.928326
# BILL_AMT4  BILL_AMT5    0.940134
# BILL_AMT6  BILL_AMT5    0.946197
# BILL_AMT2  BILL_AMT1    0.951484
# ID         ID           1.000000
# Length: 301, dtype: float64

# %%
#CHECK IF THERE'RE  CORRELATION > 0.85
# map features to their absolute correlation values
corr = credit.corr().abs()

# set equality (self correlation) as zero
corr[corr == 1] = 0

# of each feature, find the max correlation
# and sort the resulting array in ascending order
corr_cols = corr.max().sort_values(ascending=False)

# display the highly correlated features
display(corr_cols[corr_cols > 0.85])
# Out:
# BILL_AMT1    0.951484
# BILL_AMT2    0.951484
# BILL_AMT6    0.946197
# BILL_AMT5    0.946197
# BILL_AMT4    0.940134
# BILL_AMT3    0.928326
# dtype: float64

# %%
to_drop = ['BILL_AMT2','BILL_AMT4','BILL_AMT6']

# %%
#nplace to True specifies that our changes be made directly to the objec
credit.drop(to_drop,inplace=True,axis=1)

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 22 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT5                     30000 non-null int64
# PAY_AMT1                      30000 non-null int64
# PAY_AMT2                      30000 non-null int64
# PAY_AMT3                      30000 non-null int64
# PAY_AMT4                      30000 non-null int64
# PAY_AMT5                      30000 non-null int64
# PAY_AMT6                      30000 non-null int64
# default payment next month    30000 non-null int64
# dtypes: int64(22)
# memory usage: 5.0 MB

# %%
credit.corr().unstack().sort_values().drop_duplicates()
# Out:
# AGE        MARRIAGE    -0.414170
# LIMIT_BAL  PAY_2       -0.296382
#            PAY_3       -0.286123
#            PAY_0       -0.271214
# PAY_4      LIMIT_BAL   -0.267460
#                           ...
#            PAY_5        0.819835
# BILL_AMT1  BILL_AMT5    0.829779
# BILL_AMT5  BILL_AMT3    0.883910
# BILL_AMT3  BILL_AMT1    0.892279
# ID         ID           1.000000
# Length: 232, dtype: float64

# %%
to_drop2 = ['BILL_AMT3','BILL_AMT5']
#nplace to True specifies that our changes be made directly to the objec
credit.drop(to_drop2,inplace=True,axis=1)

# %%
credit.corr().unstack().sort_values().drop_duplicates()
# Out:
# MARRIAGE   AGE         -0.414170
# PAY_2      LIMIT_BAL   -0.296382
# PAY_3      LIMIT_BAL   -0.286123
# LIMIT_BAL  PAY_0       -0.271214
# PAY_4      LIMIT_BAL   -0.267460
#                           ...
# PAY_2      PAY_3        0.766552
# PAY_4      PAY_3        0.777359
# PAY_6      PAY_5        0.816900
# PAY_4      PAY_5        0.819835
# ID         ID           1.000000
# Length: 191, dtype: float64

# %%
#CHECK IF THERE'RE OTHER CORRELATION > 0.85
# map features to their absolute correlation values
corr = credit.corr().abs()

# set equality (self correlation) as zero
corr[corr == 1] = 0

# of each feature, find the max correlation
# and sort the resulting array in ascending order
corr_cols = corr.max().sort_values(ascending=False)

# display the highly correlated features
display(corr_cols[corr_cols > 0.85])
# Out:
# Series([], dtype: float64)

# %% [markdown]
# # Changing the Index of a DataFrame

# %%
#verify possible index column
credit['ID'].is_unique
# Out:
# True

# %%
#Let’s replace the existing index with column ID  using set_index:
credit.set_index('ID')
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 1          20000    2          2         1   24      2      2     -1     -1
# 2         120000    2          2         2   26     -1      2      0      0
# 3          90000    2          2         2   34      0      0      0      0
# 4          50000    2          2         1   37      0      0      0      0
# 5          50000    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29996     220000    1          3         1   39      0      0      0      0
# 29997     150000    1          3         2   43     -1     -1     -1     -1
# 29998      30000    1          2         2   37      4      3      2     -1
# 29999      80000    1          3         1   41      1     -1      0      0
# 30000      50000    1          2         1   46      0      0      0      0
#
#        PAY_5  PAY_6  BILL_AMT1  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# ID
# 1         -2     -2       3913         0       689         0         0
# 2          0      2       2682         0      1000      1000      1000
# 3          0      0      29239      1518      1500      1000      1000
# 4          0      0      46990      2000      2019      1200      1100
# 5          0      0       8617      2000     36681     10000      9000
# ...      ...    ...        ...       ...       ...       ...       ...
# 29996      0      0     188948      8500     20000      5003      3047
# 29997      0      0       1683      1837      3526      8998       129
# 29998      0      0       3565         0         0     22000      4200
# 29999      0     -1      -1645     85900      3409      1178      1926
# 30000      0      0      47929      2078      1800      1430      1000
#
#        PAY_AMT5  PAY_AMT6  default payment next month
# ID
# 1             0         0                           1
# 2             0      2000                           1
# 3          1000      5000                           0
# 4          1069      1000                           0
# 5           689       679                           0
# ...         ...       ...                         ...
# 29996      5000      1000                           0
# 29997         0         0                           0
# 29998      2000      3100                           1
# 29999     52964      1804                           1
# 30000      1000      1000                           1
#
# [30000 rows x 19 columns]

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6  BILL_AMT1  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# 0     -2     -2       3913         0       689         0         0         0
# 1      0      2       2682         0      1000      1000      1000         0
# 2      0      0      29239      1518      1500      1000      1000      1000
# 3      0      0      46990      2000      2019      1200      1100      1069
# 4      0      0       8617      2000     36681     10000      9000       689
#
#    PAY_AMT6  default payment next month
# 0         0                           1
# 1      2000                           1
# 2      5000                           0
# 3      1000                           0
# 4       679                           0

# %%
#localize by index
credit.loc[4]
# Out:
# ID                                5
# LIMIT_BAL                     50000
# SEX                               1
# EDUCATION                         2
# MARRIAGE                          1
# AGE                              57
# PAY_0                            -1
# PAY_2                             0
# PAY_3                            -1
# PAY_4                             0
# PAY_5                             0
# PAY_6                             0
# BILL_AMT1                      8617
# PAY_AMT1                       2000
# PAY_AMT2                      36681
# PAY_AMT3                      10000
# PAY_AMT4                       9000
# PAY_AMT5                        689
# PAY_AMT6                        679
# default payment next month        0
# Name: 4, dtype: int64

# %% [markdown]
# # Data transformation

# %%
credit.mask(credit < 0)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24    2.0    2.0    NaN
# 1          2     120000    2          2         2   26    NaN    2.0    0.0
# 2          3      90000    2          2         2   34    0.0    0.0    0.0
# 3          4      50000    2          2         1   37    0.0    0.0    0.0
# 4          5      50000    1          2         1   57    NaN    0.0    NaN
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39    0.0    0.0    0.0
# 29996  29997     150000    1          3         2   43    NaN    NaN    NaN
# 29997  29998      30000    1          2         2   37    4.0    3.0    2.0
# 29998  29999      80000    1          3         1   41    1.0    NaN    0.0
# 29999  30000      50000    1          2         1   46    0.0    0.0    0.0
#
#        PAY_4  PAY_5  PAY_6  BILL_AMT1  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# 0        NaN    NaN    NaN     3913.0         0       689         0         0
# 1        0.0    0.0    2.0     2682.0         0      1000      1000      1000
# 2        0.0    0.0    0.0    29239.0      1518      1500      1000      1000
# 3        0.0    0.0    0.0    46990.0      2000      2019      1200      1100
# 4        0.0    0.0    0.0     8617.0      2000     36681     10000      9000
# ...      ...    ...    ...        ...       ...       ...       ...       ...
# 29995    0.0    0.0    0.0   188948.0      8500     20000      5003      3047
# 29996    NaN    0.0    0.0     1683.0      1837      3526      8998       129
# 29997    NaN    0.0    0.0     3565.0         0         0     22000      4200
# 29998    0.0    0.0    NaN        NaN     85900      3409      1178      1926
# 29999    0.0    0.0    0.0    47929.0      2078      1800      1430      1000
#
#        PAY_AMT5  PAY_AMT6  default payment next month
# 0             0         0                           1
# 1             0      2000                           1
# 2          1000      5000                           0
# 3          1069      1000                           0
# 4           689       679                           0
# ...         ...       ...                         ...
# 29995      5000      1000                           0
# 29996         0         0                           0
# 29997      2000      3100                           1
# 29998     52964      1804                           1
# 29999      1000      1000                           1
#
# [30000 rows x 20 columns]

# %%
#rename columns name
credit.rename(columns={"default payment next month":"NEXT_DEFAULT"})
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  PAY_5  PAY_6  BILL_AMT1  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# 0         -1     -2     -2       3913         0       689         0         0
# 1          0      0      2       2682         0      1000      1000      1000
# 2          0      0      0      29239      1518      1500      1000      1000
# 3          0      0      0      46990      2000      2019      1200      1100
# 4          0      0      0       8617      2000     36681     10000      9000
# ...      ...    ...    ...        ...       ...       ...       ...       ...
# 29995      0      0      0     188948      8500     20000      5003      3047
# 29996     -1      0      0       1683      1837      3526      8998       129
# 29997     -1      0      0       3565         0         0     22000      4200
# 29998      0      0     -1      -1645     85900      3409      1178      1926
# 29999      0      0      0      47929      2078      1800      1430      1000
#
#        PAY_AMT5  PAY_AMT6  NEXT_DEFAULT
# 0             0         0             1
# 1             0      2000             1
# 2          1000      5000             0
# 3          1069      1000             0
# 4           689       679             0
# ...         ...       ...           ...
# 29995      5000      1000             0
# 29996         0         0             0
# 29997      2000      3100             1
# 29998     52964      1804             1
# 29999      1000      1000             1
#
# [30000 rows x 20 columns]

# %%
#rename columns using a map
new_names = {'PAY_0':'PAY_SET',
            'PAY_2':'PAY_AGO',
            'PAY_3':'PAY_JUL',
            'PAY_4':'PAY_JUN',
            'PAY_5':'PAY_MAY',
            'PAY_6':'PAY_APR',
            'BILL_AMT1':'BILL_AMT_SET',
            'BILL_AMT2':'BILL_AMT_AGO',
            'BILL_AMT3':'BILL_AMT_JUL',
            'BILL_AMT4':'BILL_AMT_JUN',
            'BILL_AMT5':'BILL_AMT_MAY',
            'BILL_AMT6':'BILL_AMT_APR',
            'PAY_AMT1':'PAY_AMT_SET',
            'PAY_AMT2':'PAY_AMT_AGO',
            'PAY_AMT3':'PAY_AMT_JUL',
            'PAY_AMT4':'PAY_AMT_JUN',
            'PAY_AMT5':'PAY_AMT_MAY',
            'PAY_AMT6':'PAY_AMT_APR',
            'default payment next month':"NEXT_DEFAULT"}

# %%
credit.rename(columns=new_names,inplace=True)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_SET  PAY_AGO  PAY_JUL  \
# 0   1      20000    2          2         1   24        2        2       -1
# 1   2     120000    2          2         2   26       -1        2        0
# 2   3      90000    2          2         2   34        0        0        0
# 3   4      50000    2          2         1   37        0        0        0
# 4   5      50000    1          2         1   57       -1        0       -1
#
#    PAY_JUN  PAY_MAY  PAY_APR  BILL_AMT_SET  PAY_AMT_SET  PAY_AMT_AGO  \
# 0       -1       -2       -2          3913            0          689
# 1        0        0        2          2682            0         1000
# 2        0        0        0         29239         1518         1500
# 3        0        0        0         46990         2000         2019
# 4        0        0        0          8617         2000        36681
#
#    PAY_AMT_JUL  PAY_AMT_JUN  PAY_AMT_MAY  PAY_AMT_APR  NEXT_DEFAULT
# 0            0            0            0            0             1
# 1         1000         1000            0         2000             1
# 2         1000         1000         1000         5000             0
# 3         1200         1100         1069         1000             0
# 4        10000         9000          689          679             0

# %% [markdown]
# ## Write to new csv file

# %%
credit.to_csv('C:\\Util\\Cenfotec\\Module5_Task2\\default of credit card clients_new.csv')

# %% [markdown]
# # Exploratory Data analysis (EDA)

# %%
#https://en.wikipedia.org/wiki/Exploratory_data_analysis

# %%
#--------------------------Histograms

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#column names in our dataframe 
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_SET',
#        'PAY_AGO', 'PAY_JUL', 'PAY_JUN', 'PAY_MAY', 'PAY_APR', 'BILL_AMT_SET',
#        'PAY_AMT_SET', 'PAY_AMT_AGO', 'PAY_AMT_JUL', 'PAY_AMT_JUN',
#        'PAY_AMT_MAY', 'PAY_AMT_APR', 'NEXT_DEFAULT'],
#       dtype='object')

# %%
#first histogram using the .hist method of matplotlib
plt.hist(credit['LIMIT_BAL'])
plt.xlabel('Frequency',fontsize=15)
plt.ylabel("Quantity",fontsize=15)
plt.title('LIMIT_BAL')
plt.show()

# %%
plt.hist(credit['LIMIT_BAL'], bins=5)
plt.xlabel('Frequency',fontsize=15)
plt.ylabel("Quantity",fontsize=15)
plt.title('LIMIT_BAL')
plt.show()

# %%
bins = 5;
plt.style.use('seaborn-deep')
plt.hist(credit['PAY_SET'],bins,label='Set')
plt.hist(credit['PAY_AGO'],bins,label='Ago')
plt.hist(credit['PAY_JUL'],bins,label='Jul')
plt.hist(credit['PAY_JUN'],bins,label='Jun')
plt.hist(credit['PAY_MAY'],bins,label='May')
plt.hist(credit['PAY_APR'],bins,label='Apr')
plt.xlabel('Frequency',fontsize=15)
plt.ylabel("Quantity",fontsize=15)
plt.title('PAY BY MONTH')
plt.legend(loc='upper right')
plt.show()

# %%
bins = 5;
plt.style.use('seaborn-deep')
plt.hist([credit['PAY_SET'],credit['PAY_AGO'],credit['PAY_JUL'],credit['PAY_JUN'],credit['PAY_MAY'],credit['PAY_APR']]
         ,bins,label=['Set','Ago','Jul','Jun','May','Apr'])
plt.xlabel('Frequency',fontsize=15)
plt.ylabel("Quantity",fontsize=15)
plt.title('PAY BY MONTH')
plt.legend(loc='upper right')
plt.show()

# %%
bins = 5;
plt.style.use('seaborn-deep')
plt.hist([credit['PAY_AMT_SET'],credit['PAY_AMT_AGO'],credit['PAY_AMT_JUL'],credit['PAY_AMT_JUN'],credit['PAY_AMT_MAY'],credit['PAY_AMT_APR']]
         ,bins,label=['Set','Ago','Jul','Jun','May','Apr'])
plt.xlabel('Frequency',fontsize=15)
plt.ylabel("Quantity",fontsize=15)
plt.title('PAY AMT BY MONTH')
plt.legend(loc='upper right')
plt.show()

# %%
#---------------------------- Line Plots
#used in EDA to illustrate the range and mode of any given numerical variable. This can be very important 
#for things like preventing bias and model overfit and even identifying collinearity

# %%
plt.plot(credit['LIMIT_BAL'])
plt.xlabel('Frequency',fontsize=15)
plt.ylabel("Quantity",fontsize=15)
plt.title('LIMIT_BAL')
plt.show()

# %%
#--------------------Scatter Plots
#This is very useful for understanding any possible relationships between the data, 
#but as you are aware, does not always point to any causal relationship

# %%
x = credit['PAY_SET']
y = credit['PAY_JUL']

# %%
plt.scatter(x,y)
plt.show()

# %%
N= 50
colors = np.random.normal(size=30000)
size = np.random.randint(10, 220, size=N)
fig, ax = plt.subplots()
scatter = plt.scatter(x,y,c=colors,s=size)
# produce a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="lower left", title="Classes")
ax.add_artist(legend1)

# produce a legend with a cross section of sizes from the scatter
handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6)
legend2 = ax.legend(handles, labels, loc="upper right", title="Sizes")

# %%
#----------------------------------- Box Plots
#called Box and Whisker Plots, are very useful for quickly visualizing where the bulk of the data
#is in any given feature ad are also very useful 
#for identifying feature with outliers or extreme variances in the observations

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_SET',
#        'PAY_AGO', 'PAY_JUL', 'PAY_JUN', 'PAY_MAY', 'PAY_APR', 'BILL_AMT_SET',
#        'PAY_AMT_SET', 'PAY_AMT_AGO', 'PAY_AMT_JUL', 'PAY_AMT_JUN',
#        'PAY_AMT_MAY', 'PAY_AMT_APR', 'NEXT_DEFAULT'],
#       dtype='object')

# %%
A = credit['BILL_AMT_SET']
plt.boxplot(A,0,'gD')
plt.show()

# %%
PMSET = credit['PAY_AMT_SET']
plt.boxplot(PMSET,0,'gD')
plt.show()

# %%
LB = credit['LIMIT_BAL']
plt.boxplot(LB,0,'gD')
plt.show()

# %%
PSET = credit['PAY_SET']
plt.boxplot(PSET,0,'gD')
plt.show()

# %% [markdown]
# # Correlation

# %%
corrMat = credit.corr()
print(corrMat)
# Out:
#                     ID  LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE  \
# ID            1.000000   0.026179  0.018497   0.039177 -0.029079  0.018678
# LIMIT_BAL     0.026179   1.000000  0.024755  -0.219161 -0.108139  0.144713
# SEX           0.018497   0.024755  1.000000   0.014232 -0.031389 -0.090874
# EDUCATION     0.039177  -0.219161  0.014232   1.000000 -0.143464  0.175061
# MARRIAGE     -0.029079  -0.108139 -0.031389  -0.143464  1.000000 -0.414170
# AGE           0.018678   0.144713 -0.090874   0.175061 -0.414170  1.000000
# PAY_SET      -0.030575  -0.271214 -0.057643   0.105364  0.019917 -0.039447
# PAY_AGO      -0.011215  -0.296382 -0.070771   0.121566  0.024199 -0.050148
# PAY_JUL      -0.018494  -0.286123 -0.066096   0.114025  0.032688 -0.053048
# PAY_JUN      -0.002735  -0.267460 -0.060173   0.108793  0.033122 -0.049722
# PAY_MAY      -0.022199  -0.249411 -0.055064   0.097520  0.035629 -0.053826
# PAY_APR      -0.020270  -0.235195 -0.044008   0.082316  0.034345 -0.048773
# BILL_AMT_SET  0.019389   0.285430 -0.033642   0.023581 -0.023472  0.056239
# PAY_AMT_SET   0.009742   0.195236 -0.000242  -0.037456 -0.005979  0.026147
# PAY_AMT_AGO   0.008406   0.178408 -0.001391  -0.030038 -0.008093  0.021785
# PAY_AMT_JUL   0.039151   0.210167 -0.008597  -0.039943 -0.003541  0.029247
# PAY_AMT_JUN   0.007793   0.203242 -0.002229  -0.038218 -0.012659  0.021379
# PAY_AMT_MAY   0.000652   0.217202 -0.001667  -0.040358 -0.001205  0.022850
# PAY_AMT_APR   0.003000   0.219595 -0.002766  -0.037200 -0.006641  0.019478
# NEXT_DEFAULT -0.013952  -0.153520 -0.039961   0.028006 -0.024339  0.013890
#
#                PAY_SET   PAY_AGO   PAY_JUL   PAY_JUN   PAY_MAY   PAY_APR  \
# ID           -0.030575 -0.011215 -0.018494 -0.002735 -0.022199 -0.020270
# LIMIT_BAL    -0.271214 -0.296382 -0.286123 -0.267460 -0.249411 -0.235195
# SEX          -0.057643 -0.070771 -0.066096 -0.060173 -0.055064 -0.044008
# EDUCATION     0.105364  0.121566  0.114025  0.108793  0.097520  0.082316
# MARRIAGE      0.019917  0.024199  0.032688  0.033122  0.035629  0.034345
# AGE          -0.039447 -0.050148 -0.053048 -0.049722 -0.053826 -0.048773
# PAY_SET       1.000000  0.672164  0.574245  0.538841  0.509426  0.474553
# PAY_AGO       0.672164  1.000000  0.766552  0.662067  0.622780  0.575501
# PAY_JUL       0.574245  0.766552  1.000000  0.777359  0.686775  0.632684
# PAY_JUN       0.538841  0.662067  0.777359  1.000000  0.819835  0.716449
# PAY_MAY       0.509426  0.622780  0.686775  0.819835  1.000000  0.816900
# PAY_APR       0.474553  0.575501  0.632684  0.716449  0.816900  1.000000
# BILL_AMT_SET  0.187068  0.234887  0.208473  0.202812  0.206684  0.207373
# PAY_AMT_SET  -0.079269 -0.080701  0.001295 -0.009362 -0.006089 -0.001496
# PAY_AMT_AGO  -0.070101 -0.058990 -0.066793 -0.001944 -0.003191 -0.005223
# PAY_AMT_JUL  -0.070561 -0.055901 -0.053311 -0.069235  0.009062  0.005834
# PAY_AMT_JUN  -0.064005 -0.046858 -0.046067 -0.043461 -0.058299  0.019018
# PAY_AMT_MAY  -0.058190 -0.037093 -0.035863 -0.033590 -0.033337 -0.046434
# PAY_AMT_APR  -0.058673 -0.036500 -0.035861 -0.026565 -0.023027 -0.025299
# NEXT_DEFAULT  0.324794  0.263551  0.235253  0.216614  0.204149  0.186866
#
#               BILL_AMT_SET  PAY_AMT_SET  PAY_AMT_AGO  PAY_AMT_JUL  \
# ID                0.019389     0.009742     0.008406     0.039151
# LIMIT_BAL         0.285430     0.195236     0.178408     0.210167
# SEX              -0.033642    -0.000242    -0.001391    -0.008597
# EDUCATION         0.023581    -0.037456    -0.030038    -0.039943
# MARRIAGE         -0.023472    -0.005979    -0.008093    -0.003541
# AGE               0.056239     0.026147     0.021785     0.029247
# PAY_SET           0.187068    -0.079269    -0.070101    -0.070561
# PAY_AGO           0.234887    -0.080701    -0.058990    -0.055901
# PAY_JUL           0.208473     0.001295    -0.066793    -0.053311
# PAY_JUN           0.202812    -0.009362    -0.001944    -0.069235
# PAY_MAY           0.206684    -0.006089    -0.003191     0.009062
# PAY_APR           0.207373    -0.001496    -0.005223     0.005834
# BILL_AMT_SET      1.000000     0.140277     0.099355     0.156887
# PAY_AMT_SET       0.140277     1.000000     0.285576     0.252191
# PAY_AMT_AGO       0.099355     0.285576     1.000000     0.244770
# PAY_AMT_JUL       0.156887     0.252191     0.244770     1.000000
# PAY_AMT_JUN       0.158303     0.199558     0.180107     0.216325
# PAY_AMT_MAY       0.167026     0.148459     0.180908     0.159214
# PAY_AMT_APR       0.179341     0.185735     0.157634     0.162740
# NEXT_DEFAULT     -0.019644    -0.072929    -0.058579    -0.056250
#
#               PAY_AMT_JUN  PAY_AMT_MAY  PAY_AMT_APR  NEXT_DEFAULT
# ID               0.007793     0.000652     0.003000     -0.013952
# LIMIT_BAL        0.203242     0.217202     0.219595     -0.153520
# SEX             -0.002229    -0.001667    -0.002766     -0.039961
# EDUCATION       -0.038218    -0.040358    -0.037200      0.028006
# MARRIAGE        -0.012659    -0.001205    -0.006641     -0.024339
# AGE              0.021379     0.022850     0.019478      0.013890
# PAY_SET         -0.064005    -0.058190    -0.058673      0.324794
# PAY_AGO         -0.046858    -0.037093    -0.036500      0.263551
# PAY_JUL         -0.046067    -0.035863    -0.035861      0.235253
# PAY_JUN         -0.043461    -0.033590    -0.026565      0.216614
# PAY_MAY         -0.058299    -0.033337    -0.023027      0.204149
# PAY_APR          0.019018    -0.046434    -0.025299      0.186866
# BILL_AMT_SET     0.158303     0.167026     0.179341     -0.019644
# PAY_AMT_SET      0.199558     0.148459     0.185735     -0.072929
# PAY_AMT_AGO      0.180107     0.180908     0.157634     -0.058579
# PAY_AMT_JUL      0.216325     0.159214     0.162740     -0.056250
# PAY_AMT_JUN      1.000000     0.151830     0.157834     -0.056827
# PAY_AMT_MAY      0.151830     1.000000     0.154896     -0.055124
# PAY_AMT_APR      0.157834     0.154896     1.000000     -0.053183
# NEXT_DEFAULT    -0.056827    -0.055124    -0.053183      1.000000

# %% [markdown]
# # Covariance

# %%
#The positive covariance >> when one variable grows the other variable too. They have a direct relationship.
#The negative covariance >> when one variable grows the other variable decreases. They have a reverse relationship.
covMat = credit.cov()
print(covMat)
# Out:
#                         ID     LIMIT_BAL          SEX     EDUCATION  \
# ID            7.500250e+07  2.941664e+07    78.356379    268.154338
# LIMIT_BAL     2.941664e+07  1.683446e+10  1571.050630 -22474.028945
# SEX           7.835638e+01  1.571051e+03     0.239247      0.005502
# EDUCATION     2.681543e+02 -2.247403e+04     0.005502      0.624651
# MARRIAGE     -1.314525e+02 -7.323670e+03    -0.008014     -0.059184
# AGE           1.491057e+03  1.730767e+05    -0.409726      1.275380
# PAY_SET      -2.975726e+02 -3.954593e+04    -0.031685      0.093584
# PAY_AGO      -1.162770e+02 -4.603765e+04    -0.041442      0.115025
# PAY_JUL      -1.916922e+02 -4.443225e+04    -0.038694      0.107861
# PAY_JUN      -2.769132e+01 -4.057181e+04    -0.034411      0.100528
# PAY_MAY      -2.178600e+02 -3.667056e+04    -0.030521      0.087340
# PAY_APR      -2.018774e+02 -3.509308e+04    -0.024754      0.074816
# BILL_AMT_SET  1.236447e+07  2.727020e+09 -1211.694332   1372.377644
# PAY_AMT_SET   1.397501e+06  4.195711e+08    -1.964266   -490.330155
# PAY_AMT_AGO   1.677383e+06  5.333504e+08   -15.675500   -547.005021
# PAY_AMT_JUL   5.969803e+06  4.801180e+08   -74.034812   -555.834305
# PAY_AMT_JUN   1.057334e+06  4.131202e+08   -17.080110   -473.206951
# PAY_AMT_MAY   8.629502e+04  4.305657e+08   -12.458809   -487.335947
# PAY_AMT_APR   4.618460e+05  5.065153e+08   -24.051885   -522.673379
# NEXT_DEFAULT -5.015171e+01 -8.267552e+03    -0.008113      0.009187
#
#                  MARRIAGE            AGE       PAY_SET       PAY_AGO  \
# ID            -131.452515    1491.057019   -297.572636   -116.276959
# LIMIT_BAL    -7323.669658  173076.722569 -39545.930009 -46037.648360
# SEX             -0.008014      -0.409726     -0.031685     -0.041442
# EDUCATION       -0.059184       1.275380      0.093584      0.115025
# MARRIAGE         0.272452      -1.992764      0.011683      0.015122
# AGE             -1.992764      84.969755     -0.408639     -0.553408
# PAY_SET          0.011683      -0.408639      1.262930      0.904330
# PAY_AGO          0.015122      -0.553408      0.904330      1.433254
# PAY_JUL          0.020421      -0.585263      0.772384      1.098371
# PAY_JUN          0.020213      -0.535851      0.707972      0.926680
# PAY_MAY          0.021074      -0.562245      0.648743      0.844886
# PAY_APR          0.020616      -0.517022      0.613292      0.792320
# BILL_AMT_SET  -902.154685   38172.933546  15480.304170  20706.614217
# PAY_AMT_SET    -51.691615    3992.041735  -1475.495089  -1600.240756
# PAY_AMT_AGO    -97.327974    4626.861549  -1815.138407  -1627.192336
# PAY_AMT_JUL    -32.546082    4746.824393  -1396.168258  -1178.331282
# PAY_AMT_JUN   -103.518204    3087.324192  -1126.847945   -878.843879
# PAY_AMT_MAY     -9.607709    3218.052172   -999.107730   -678.468530
# PAY_AMT_APR    -61.623271    3191.903901  -1172.193614   -776.835035
# NEXT_DEFAULT    -0.005273       0.053143      0.151499      0.130960
#
#                    PAY_JUL       PAY_JUN       PAY_MAY       PAY_APR  \
# ID             -191.692156    -27.691323   -217.860029   -201.877379
# LIMIT_BAL    -44432.253315 -40571.811859 -36670.562325 -35093.083441
# SEX              -0.038694     -0.034411     -0.030521     -0.024754
# EDUCATION         0.107861      0.100528      0.087340      0.074816
# MARRIAGE          0.020421      0.020213      0.021074      0.020616
# AGE              -0.585263     -0.535851     -0.562245     -0.517022
# PAY_SET           0.772384      0.707972      0.648743      0.613292
# PAY_AGO           1.098371      0.926680      0.844886      0.792320
# PAY_JUL           1.432492      1.087761      0.931455      0.870815
# PAY_JUN           1.087761      1.366885      1.086161      0.963263
# PAY_MAY           0.931455      1.086161      1.284114      1.064545
# PAY_APR           0.870815      0.963263      1.064545      1.322472
# BILL_AMT_SET  18373.210469  17460.198259  17246.377531  17560.424872
# PAY_AMT_SET      25.668468   -181.295613   -114.281714    -28.500666
# PAY_AMT_AGO   -1841.952825    -52.358166    -83.324487   -138.399452
# PAY_AMT_JUL   -1123.428782  -1425.205189    180.812142    118.121022
# PAY_AMT_JUN    -863.762183   -796.035739  -1034.961970    342.623730
# PAY_AMT_MAY    -655.796002   -599.991629   -577.161017   -815.832688
# PAY_AMT_APR    -763.026041   -552.137338   -463.892613   -517.216277
# NEXT_DEFAULT      0.116867      0.105115      0.096020      0.089194
#
#               BILL_AMT_SET   PAY_AMT_SET   PAY_AMT_AGO   PAY_AMT_JUL  \
# ID            1.236447e+07  1.397501e+06  1.677383e+06  5.969803e+06
# LIMIT_BAL     2.727020e+09  4.195711e+08  5.333504e+08  4.801180e+08
# SEX          -1.211694e+03 -1.964266e+00 -1.567550e+01 -7.403481e+01
# EDUCATION     1.372378e+03 -4.903302e+02 -5.470050e+02 -5.558343e+02
# MARRIAGE     -9.021547e+02 -5.169161e+01 -9.732797e+01 -3.254608e+01
# AGE           3.817293e+04  3.992042e+03  4.626862e+03  4.746824e+03
# PAY_SET       1.548030e+04 -1.475495e+03 -1.815138e+03 -1.396168e+03
# PAY_AGO       2.070661e+04 -1.600241e+03 -1.627192e+03 -1.178331e+03
# PAY_JUL       1.837321e+04  2.566847e+01 -1.841953e+03 -1.123429e+03
# PAY_JUN       1.746020e+04 -1.812956e+02 -5.235817e+01 -1.425205e+03
# PAY_MAY       1.724638e+04 -1.142817e+02 -8.332449e+01  1.808121e+02
# PAY_APR       1.756042e+04 -2.850067e+01 -1.383995e+02  1.181210e+02
# BILL_AMT_SET  5.422240e+09  1.710894e+08  1.685692e+08  2.034048e+08
# PAY_AMT_SET   1.710894e+08  2.743423e+08  1.089849e+08  7.354626e+07
# PAY_AMT_AGO   1.685692e+08  1.089849e+08  5.308817e+08  9.929841e+07
# PAY_AMT_JUL   2.034048e+08  7.354626e+07  9.929841e+07  3.100051e+08
# PAY_AMT_JUN   1.826164e+08  5.178189e+07  6.501168e+07  5.966970e+07
# PAY_AMT_MAY   1.879091e+08  3.756893e+07  6.368414e+07  4.282921e+07
# PAY_AMT_APR   2.347681e+08  5.469033e+07  6.456816e+07  5.093879e+07
# NEXT_DEFAULT -6.003941e+02 -5.013746e+02 -5.602107e+02 -4.110763e+02
#
#                PAY_AMT_JUN   PAY_AMT_MAY   PAY_AMT_APR  NEXT_DEFAULT
# ID            1.057334e+06  8.629502e+04  4.618460e+05    -50.151705
# LIMIT_BAL     4.131202e+08  4.305657e+08  5.065153e+08  -8267.551759
# SEX          -1.708011e+01 -1.245881e+01 -2.405188e+01     -0.008113
# EDUCATION    -4.732070e+02 -4.873359e+02 -5.226734e+02      0.009187
# MARRIAGE     -1.035182e+02 -9.607709e+00 -6.162327e+01     -0.005273
# AGE           3.087324e+03  3.218052e+03  3.191904e+03      0.053143
# PAY_SET      -1.126848e+03 -9.991077e+02 -1.172194e+03      0.151499
# PAY_AGO      -8.788439e+02 -6.784685e+02 -7.768350e+02      0.130960
# PAY_JUL      -8.637622e+02 -6.557960e+02 -7.630260e+02      0.116867
# PAY_JUN      -7.960357e+02 -5.999916e+02 -5.521373e+02      0.105115
# PAY_MAY      -1.034962e+03 -5.771610e+02 -4.638926e+02      0.096020
# PAY_APR       3.426237e+02 -8.158327e+02 -5.172163e+02      0.089194
# BILL_AMT_SET  1.826164e+08  1.879091e+08  2.347681e+08   -600.394108
# PAY_AMT_SET   5.178189e+07  3.756893e+07  5.469033e+07   -501.374552
# PAY_AMT_AGO   6.501168e+07  6.368414e+07  6.456816e+07   -560.210740
# PAY_AMT_JUL   5.966970e+07  4.282921e+07  5.093879e+07   -411.076284
# PAY_AMT_JUN   2.454286e+08  3.634098e+07  4.395747e+07   -369.515887
# PAY_AMT_MAY   3.634098e+07  2.334266e+08  4.207110e+07   -349.562530
# PAY_AMT_APR   4.395747e+07  4.207110e+07  3.160383e+08   -392.426415
# NEXT_DEFAULT -3.695159e+02 -3.495625e+02 -3.924264e+02      0.172276
